# %%
import pandas as pd
import folium

# df18.to_excel('results/precipitation_record_and_estimation_final.xlsx', index=False)
df18 = pd.read_excel('precipitation_record_and_estimation_final.xlsx')

# %%
# Create a map object centered on the mean of the coordinates
mean_lat = df18['POINT_Y'].mean()
mean_lon = df18['POINT_X'].mean()
world_map = folium.Map(location=[mean_lat, mean_lon], zoom_start=4)

# Add markers for each location in the DataFrame
for i in range(0, len(df18)):
    if df18.iloc[i]['r2'] >= 0.6:
        color = 'green'
    elif df18.iloc[i]['r2'] < 0.6:
        color = 'red'
    else:
        color = 'black'
    folium.Marker(location=[df18.iloc[i]['POINT_Y'], df18.iloc[i]['POINT_X']],
                  popup=f"{df18.iloc[i]['nombre']} ({df18.iloc[i]['codigo_estacion']}) ({df18.iloc[i]['r2']}) ({df18.iloc[i]['count']})",
                  icon=folium.Icon(color=color)).add_to(world_map)


# Display the map
world_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_2fdfe3470c1e9d84ef9019049300cb3d {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_2fdfe3470c1e9d84ef9019049300cb3d&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_2fdfe3470c1e9d84ef9019049300cb3d = L.map(
#                 &quot;map_2fdfe3470c1e9d84ef9019049300cb3d&quot;,
#                 {
#                     center: [-35.190444069350406, -71.15456153565191],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 4,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_6e34db059a5a77805747c8552102041d = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_2fdfe3470c1e9d84ef9019049300cb3d);
#
#
#             var marker_0ab40bc651b334c1a2576768e317fb5b = L.marker(
#                 [-46.2882469366, -72.86964553919998],
#                 {}
#             ).addTo(map_2fdfe3470c1e9d84ef9019049300cb3d);
#
#
#             var icon_f154500ca840550659f84e13c077bb0c = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_0ab40bc651b334c1a2576768e317fb5b.setIcon(icon_f154500ca840550659f84e13c077bb0c);
#
#
#         var popup_cff2d25c598bf0f58dc69baef166fffa = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_671aabf10dc8de9b4c46a92bdd98ce68 = $(`&lt;div id=&quot;html_671aabf10dc8de9b4c46a92bdd98ce68&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Rio Murta En Desembocadura (11514001) (0.9999999999999998) (2)&lt;/div&gt;`)[0];
#                 popup_cff2d25c598bf0f58dc69baef166fffa.setContent(html_671aabf10dc8de9b4c46a92bdd98ce68);
#
#
#
#         marker_0ab40bc651b334c1a2576768e317fb5b.bindPopup(popup_cff2d25c598bf0f58dc69baef166fffa)
#         ;
#
#
#
#
#             var marker_3b73c9e149c6a77501aeb1ab8bbc6b0e = L.marker(
#                 [-36.6283424755, -72.38397897369998],
#                 {}
#             ).addTo(map_2fdfe3470c1e9d84ef9019049300cb3d);
#
#
#             var icon_3b314aacfc833c42e30a30b0acbc305e = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_3b73c9e149c6a77501aeb1ab8bbc6b0e.setIcon(icon_3b314aacfc833c42e30a30b0acbc305e);
#
#
#         var popup_f602fddece8a04f929cf66816ea6073e = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_49a5066c705a7d65d7f70907953cda35 = $(`&lt;div id=&quot;html_49a5066c705a7d65d7f70907953cda35&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Rio ÑUble En Confluencia (8119002) (0.9999999999999947) (2)&lt;/div&gt;`)[0];
#                 popup_f602fddece8a04f929cf66816ea6073e.setContent(html_49a5066c705a7d65d7f70907953cda35);
#
#
#
#         marker_3b73c9e149c6a77501aeb1ab8bbc6b0e.bindPopup(popup_f602fddece8a04f929cf66816ea6073e)
#         ;
#
#
#
#
#             var marker_89b238a918e1fcd2e228ff18b286492a = L.marker(
#                 [-33.6470254821, -78.8466906074],
#                 {}
#             ).addTo(map_2fdfe3470c1e9d84ef9019049300cb3d);
#
#
#             var icon_274690fc7d7c99f4a6fb4d29d67cea7a = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_89b238a918e1fcd2e228ff18b286492a.setIcon(icon_274690fc7d7c99f4a6fb4d29d67cea7a);
#
#
#         var popup_7e8b06529c09b3d39735a3c1c7fa6609 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_d012410cbe814f36b5a2abeeed12191a = $(`&lt;div id=&quot;html_d012410cbe814f36b5a2abeeed12191a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Juan Fernandez Estacion Meteorologica (330031) (0.9841655764707291) (675)&lt;/div&gt;`)[0];
#                 popup_7e8b06529c09b3d39735a3c1c7fa6609.setContent(html_d012410cbe814f36b5a2abeeed12191a);
#
#
#
#         marker_89b238a918e1fcd2e228ff18b286492a.bindPopup(popup_7e8b06529c09b3d39735a3c1c7fa6609)
#         ;
#
#
#
#
#             var marker_e8b55fb57883e2a0109ed1cff3aa2450 = L.marker(
#                 [-31.656443507, -71.1441893837],
#                 {}
#             ).addTo(map
